# %%
import streamlit as st
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [20], in <cell line: 1>()
# ----> 1 import streamlit as st
#
# File ~\AppData\Roaming\Python\Python39\site-packages\streamlit\__init__.py:56, in <module>
#      53 # Give the package a version.
#      54 __version__ = _STREAMLIT_VERSION_STRING
# ---> 56 from streamlit.delta_generator import DeltaGenerator as _DeltaGenerator
#      57 from streamlit.proto.RootContainer_pb2 import RootContainer as _RootContainer
#      58 from streamlit.runtime.caching import (
#      59     cache_resource as _cache_resource,
#      60     cache_data as _cache_data,
#      61     experimental_singleton as _experimental_singleton,
#      62     experimental_memo as _experimental_memo,
#      63 )
#
# File ~\AppData\Roaming\Python\Python39\site-packages\streamlit\delta_generator.py:37, in <module>
#      34 import click
# ...

# %%
st.title("Exemple")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 st.title("Exemple")
#
# NameError: name 'st' is not defined
